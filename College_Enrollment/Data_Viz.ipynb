# %% [markdown]
# ##### data source: [My Brother's Keeper - ](https://catalog.data.gov/dataset/my-brothers-keeper-key-statistical-indicators-on-boys-and-men-of-color-83d9e/resource/99d443dc-4636-4f75-9dee-a601b3f719f8)
# >##### publisher: [National Center for Education Statistics](https://catalog.data.gov/dataset?publisher=National%20Center%20for%20Education%20Statistics%20%28NCES%29)
#
#
# >#### First, we clean the data by removing the columns that don't contain any data. In this dataset, the original authors used empty columns as vertical dividers to better visualize their data. For our purposes, we must delete them.
# >#### Seconds, we must note that some indexes are used as column headers. using `.dropna()` is not advised.

# %%
import pandas as pd
import matplotlib.pyplot as plt
class Data:
    def __init__(self):
        # performs the necessary clean-ups.
        self.data = pd.read_excel('College-enrollment-rates-trans_verified.xlsx')
        self.data.dropna()
        self.data.drop(columns=['Unnamed: 2', 'Unnamed: 4', 'Unnamed: 6', 'Unnamed: 8',
                           'Unnamed: 10', 'Unnamed: 12', 'Unnamed: 14', 'Unnamed: 16' ,
                           'Unnamed: 18', 'Unnamed: 20', 'Unnamed: 22', 'Unnamed: 24',
                          'Unnamed: 26'], index=[29,30,31,32,33,34], inplace=True)
        self.data.rename(columns={'Unnamed: 1': '2000', 'Unnamed: 3': '2001', 'Unnamed: 5': '2002', 'Unnamed: 7': '2003',
                           'Unnamed: 9': '2004', 'Unnamed: 11': '2005', 'Unnamed: 13': '2006', 'Unnamed: 15': '2007' ,
                           'Unnamed: 17': '2008', 'Unnamed: 19': '2009', 'Unnamed: 21': '2010', 'Unnamed: 23': '2011',
                          'Unnamed: 25': '2012'}, inplace=True)
        # attempts to convert data types to floating points.
        self.data.convert_dtypes()
        self.data['2000'] = pd.to_numeric(self.data['2000'], errors="coerce")
        self.data['2001'] = pd.to_numeric(self.data['2001'], errors="coerce")
        self.data['2002'] = pd.to_numeric(self.data['2002'], errors="coerce")
        self.data['2008'] = pd.to_numeric(self.data['2008'], errors="coerce")

    def variables(self):
        # Gathers the sprecific data we need using pandas
        # We create a new DataFrame from the index we choose.
        Male_White = pd.DataFrame(data.loc[14])
        Female_White = pd.DataFrame(data.loc[22])

        # We must drop the sub-heading used in the original dataframe. Remember that this subheading is an index.
        Male_White.drop(index='Percentage of 18- to 24-year-olds enrolled in 2- and 4-year colleges by sex and race/ethnicity, 2000–2012', inplace=True)
        Female_White.drop(index='Percentage of 18- to 24-year-olds enrolled in 2- and 4-year colleges by sex and race/ethnicity, 2000–2012', inplace=True)

        
    def line_plot(self):
        # Creates the plots we need for Data Visualization
        figure_1 = plt.figure()
        plt.plot(Male_White, label="White Males", color='blue')
        plt.title('White Males')
        plt.legend()
        
        figure_2 = plt.figure()
        plt.plot(Female_White, label="White Females", color='red')
        plt.title('White Females')
        plt.legend()
        
        plt.show()

    def scatter_plot(self):
        figure_1 = plt.figure()
        plt.scatter(x=Male_White[14].index, y=Male_White[14].values, label="White Males", color='blue')
        plt.title('White Males')
        plt.legend()

        figure_2 = plt.figure()
        plt.scatter(x=Female_White[22].index, y=Female_White[22].values, label="White Females", color='red')
        plt.title('White Males')
        plt.legend()

        plt.show()

# %%
Data = Data()
Data.variables()
Data.scatter_plot()

# %%
# performs the necessary clean-ups.
data = pd.read_excel('College-enrollment-rates-trans_verified.xlsx')
data.dropna()
data.drop(columns=['Unnamed: 2', 'Unnamed: 4', 'Unnamed: 6', 'Unnamed: 8',
                   'Unnamed: 10', 'Unnamed: 12', 'Unnamed: 14', 'Unnamed: 16' ,
                   'Unnamed: 18', 'Unnamed: 20', 'Unnamed: 22', 'Unnamed: 24',
                  'Unnamed: 26'], index=[29,30,31,32,33,34], inplace=True)
data.rename(columns={'Unnamed: 1': '2000', 'Unnamed: 3': '2001', 'Unnamed: 5': '2002', 'Unnamed: 7': '2003',
                   'Unnamed: 9': '2004', 'Unnamed: 11': '2005', 'Unnamed: 13': '2006', 'Unnamed: 15': '2007' ,
                   'Unnamed: 17': '2008', 'Unnamed: 19': '2009', 'Unnamed: 21': '2010', 'Unnamed: 23': '2011',
                  'Unnamed: 25': '2012'}, inplace=True)
# attempts to convert data types to floating points.
data.convert_dtypes()
data['2000'] = pd.to_numeric(data['2000'], errors="coerce")
data['2001'] = pd.to_numeric(data['2001'], errors="coerce")
data['2002'] = pd.to_numeric(data['2002'], errors="coerce")
data['2008'] = pd.to_numeric(data['2008'], errors="coerce")

# %%
# Gathers the sprecific data we need. Just select specific index numbers.
Male_White = pd.DataFrame(data.loc[14])
Female_White = pd.DataFrame(data.loc[22])
Male_White.drop(index='Percentage of 18- to 24-year-olds enrolled in 2- and 4-year colleges by sex and race/ethnicity, 2000–2012', inplace=True)
Female_White.drop(index='Percentage of 18- to 24-year-olds enrolled in 2- and 4-year colleges by sex and race/ethnicity, 2000–2012', inplace=True)

# %%
# Creates the plots we need for Data Visualization
figure_1 = plt.figure()
plt.plot(Male_White, label="White Males")
plt.title('White Males')
plt.legend()

# %%
# Creates the plots we need for Data Visualization
figure_1 = plt.figure()
plt.plot(Male_White, label="White Males")
plt.title('White Males')
plt.legend()

figure_2 = plt.figure()
plt.plot(Female_White, label="White Females")
plt.title('White Females')
plt.legend()

plt.show()
